# %% [markdown]
# # Basic Statistic Understanding
# ## Case : Credit Card Customers (Predict Churning Customers)

# %% [markdown]
# ### 1. Original data

# %%
#Import Library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/densaiko/data_science_learning/main/dataset/BankChurners.csv')
data = data[data.columns[:-2]]
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  ...  Total_Ct_Chng_Q4_Q1 Avg_Utilization_Ratio
# 0  768805383  Existing Customer  ...                1.625                 0.061
# 1  818770008  Existing Customer  ...                3.714                 0.105
# 2  713982108  Existing Customer  ...                2.333                 0.000
# 3  769911858  Existing Customer  ...                2.333                 0.760
# 4  709106358  Existing Customer  ...                2.500                 0.000
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 2. Numerical : Measures of Central Tendency & Measures of Dispersion
# 14 Numerical Data : Customer age, Dependent count, Months on book, etc.

# %% [markdown]
# ### Customer Age

# %%
# Mean of Customer Age in Credit Card Customers
mean = data['Customer_Age'].mean()
print("The mean of Customer Age: {:.0f}".format(round(mean,2)))

# Median of Customer Age in Credit Card Customers
median = data['Customer_Age'].median()
print("The median of Customer Age: {}".format(int(median)))

# Mode of Customer Age in Credit Card Customers
mode = data['Customer_Age'].mode()
print("The mode of Customer Age: {}".format(int(mode)))

# The standard deviation of price in Credit Card Customers
std = data['Customer_Age'].std()
print("The std Customer Age of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Customer Age: 46
# The median of Customer Age: 46
# The mode of Customer Age: 44
# The std Customer Age of Credit Card Customers: 8.02

# %% [markdown]
# ### Dependent count

# %%
# Mean of Dependent Count in Credit Card Customers
mean = data['Dependent_count'].mean()
print("The mean of Dependent Count: {:.0f}".format(round(mean,2)))

# Median of Dependent Count in Credit Card Customers
median = data['Dependent_count'].median()
print("The median of Dependent Count: {}".format(int(median)))

# Mode of Dependent Count in Credit Card Customers
mode = data['Dependent_count'].mode()
print("The mode of Dependent Count: {}".format(int(mode)))

# The standard deviation of Dependent Count in Credit Card Customers
std = data['Dependent_count'].std()
print("The std Dependent Count of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Dependent Count: 2
# The median of Dependent Count: 2
# The mode of Dependent Count: 3
# The std Dependent Count of Credit Card Customers: 1.30

# %% [markdown]
# ### Months on book

# %%
# Mean of Months on book in Credit Card Customers
mean = data['Months_on_book'].mean()
print("The mean of Months on book: {:.0f}".format(round(mean,2)))

# Median of Months on book in Credit Card Customers
median = data['Months_on_book'].median()
print("The median of Months on book: {}".format(int(median)))

# Mode of Months on book in Credit Card Customers
mode = data['Months_on_book'].mode()
print("The mode of Months on book: {}".format(int(mode)))

# The standard deviation of Months on book in Credit Card Customers
std = data['Months_on_book'].std()
print("The std Months on book of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Months on book: 36
# The median of Months on book: 36
# The mode of Months on book: 36
# The std Months on book of Credit Card Customers: 7.99

# %% [markdown]
# ### Total relationship count

# %%
# Mean of Total telationship count in Credit Card Customers
mean = data['Total_Relationship_Count'].mean()
print("The mean of Total relationship count: {:.0f}".format(round(mean,2)))

# Median of Months on book in Credit Card Customers
median = data['Total_Relationship_Count'].median()
print("The median of Total relationship count: {}".format(int(median)))

# Mode of Months on book in Credit Card Customers
mode = data['Total_Relationship_Count'].mode()
print("The mode of Total relationship count: {}".format(int(mode)))

# The standard deviation of Total relationship count in Credit Card Customers
std = data['Total_Relationship_Count'].std()
print("The std Total relationship count of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Total relationship count: 4
# The median of Total relationship count: 4
# The mode of Total relationship count: 3
# The std Total relationship count of Credit Card Customers: 1.55

# %% [markdown]
# ### Months inactive 12 month

# %%
# Mean of Months inactive 12 month count in Credit Card Customers
mean = data['Months_Inactive_12_mon'].mean()
print("The mean of Months inactive 12 month: {:.0f}".format(round(mean,2)))

# Median of Months inactive 12 month in Credit Card Customers
median = data['Months_Inactive_12_mon'].median()
print("The median of Months inactive 12 month: {}".format(int(median)))

# Mode of Months inactive 12 month in Credit Card Customers
mode = data['Months_Inactive_12_mon'].mode()
print("The mode of Months inactive 12 month: {}".format(int(mode)))

# The standard deviation of Months inactive 12 month in Credit Card Customers
std = data['Months_Inactive_12_mon'].std()
print("The std Months inactive 12 month of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Months inactive 12 month: 2
# The median of Months inactive 12 month: 2
# The mode of Months inactive 12 month: 3
# The std Months inactive 12 month of Credit Card Customers: 1.01

# %% [markdown]
# ### Contacts count 12 month

# %%
# Mean of Contacts inactive 12 month count in Credit Card Customers
mean = data['Contacts_Count_12_mon'].mean()
print("The mean of Contacts inactive 12 month: {:.0f}".format(round(mean,2)))

# Median of Contacts inactive 12 month in Credit Card Customers
median = data['Contacts_Count_12_mon'].median()
print("The median of Contacts inactive 12 month: {}".format(int(median)))

# Mode of Contacts inactive 12 month in Credit Card Customers
mode = data['Contacts_Count_12_mon'].mode()
print("The mode of Contacts inactive 12 month: {}".format(int(mode)))

# The standard deviation of Months inactive 12 month in Credit Card Customers
std = data['Contacts_Count_12_mon'].std()
print("The std Contacts inactive 12 month of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Contacts inactive 12 month: 2
# The median of Contacts inactive 12 month: 2
# The mode of Contacts inactive 12 month: 3
# The std Contacts inactive 12 month of Credit Card Customers: 1.11

# %% [markdown]
# ### Credit Limit

# %%
# Mean of Credit Limit count in Credit Card Customers
mean = data['Credit_Limit'].mean()
print("The mean of Credit Limit: {:.0f}".format(round(mean,2)))

# Median of Months inactive 12 month in Credit Card Customers
median = data['Credit_Limit'].median()
print("The median of Credit Limit: {:.0f}".format(int(median)))

# Mode of Months inactive 12 month in Credit Card Customers
mode = data['Credit_Limit'].mode()
print("The mode of Credit Limit: {:.0f}".format(int(mode)))

# The standard deviation of Credit Limit in Credit Card Customers
std = data['Credit_Limit'].std()
print("The std Credit Limit of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Credit Limit: 8632
# The median of Credit Limit: 4549
# The mode of Credit Limit: 34516
# The std Credit Limit of Credit Card Customers: 9088.78

# %% [markdown]
# ### Total Revolving Balance

# %%
# Mean of Total Revolving Balance in Credit Card Customers
mean = data['Total_Revolving_Bal'].mean()
print("The mean of Total Revolving Balance: {:.0f}".format(round(mean,2)))

# Median of Total Revolving Balance in Credit Card Customers
median = data['Total_Revolving_Bal'].median()
print("The median of Total Revolving Balance: {:.0f}".format(int(median)))

# Mode of Total Revolving Balance in Credit Card Customers
mode = data['Total_Revolving_Bal'].mode()
print("The mode of Total Revolving Balance: {:.0f}".format(int(mode)))

# The standard deviation of Total Revolving Balance in Credit Card Customers
std = data['Total_Revolving_Bal'].std()
print("The std Total Revolving Balance of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Total Revolving Balance: 1163
# The median of Total Revolving Balance: 1276
# The mode of Total Revolving Balance: 0
# The std Total Revolving Balance of Credit Card Customers: 814.99

# %% [markdown]
# ### Average open to buy

# %%
# Mean of Average open to buy in Credit Card Customers
mean = data['Avg_Open_To_Buy'].mean()
print("The mean of Average open to buy: {:.0f}".format(round(mean,2)))

# Median of Average open to buy in Credit Card Customers
median = data['Avg_Open_To_Buy'].median()
print("The median of Average open to buy: {:.0f}".format(float(median)))

# Mode of Average open to buy in Credit Card Customers
mode = data['Avg_Open_To_Buy'].mode()
print("The mode of Average open to buy: {:.0f}".format(float(mode)))

# The standard deviation of Average open to buy in Credit Card Customers
std = data['Avg_Open_To_Buy'].std()
print("The std Total Average open to buy of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Average open to buy: 7469
# The median of Average open to buy: 3474
# The mode of Average open to buy: 1438
# The std Total Average open to buy of Credit Card Customers: 9090.69

# %% [markdown]
# ### Total Amount Change Q4 over Q1

# %%
# Mean of Total Amount Change Q4 over Q1 in Credit Card Customers
mean = data['Total_Amt_Chng_Q4_Q1'].mean()
print("The mean of Total Amount Change Q4 over Q1: {:.2f}".format(round(mean,2)))

# Median of Total Amount Change Q4 over Q1 in Credit Card Customers
median = data['Total_Amt_Chng_Q4_Q1'].median()
print("The median of Total Amount Change Q4 over Q1: {:.2f}".format(float(median)))

# Mode of Total Amount Change Q4 over Q1 in Credit Card Customers
mode = data['Total_Amt_Chng_Q4_Q1'].mode()
print("The mode of Total Amount Change Q4 over Q1: {:.2f}".format(float(mode)))

# The standard deviation of Total Amount Change Q4 over Q1 in Credit Card Customers
std = data['Total_Amt_Chng_Q4_Q1'].std()
print("The std Total Amount Change Q4 over Q1 of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Total Amount Change Q4 over Q1: 0.76
# The median of Total Amount Change Q4 over Q1: 0.74
# The mode of Total Amount Change Q4 over Q1: 0.79
# The std Total Amount Change Q4 over Q1 of Credit Card Customers: 0.22

# %% [markdown]
# ### Total Transaction Amount

# %%
# Mean of Total transaction amount Credit Card Customers
mean = data['Total_Trans_Amt'].mean()
print("The mean of Total transaction amount: {:.0f}".format(round(mean,2)))

# Median of Total transaction amount in Credit Card Customers
median = data['Total_Trans_Amt'].median()
print("The median of Total transaction amount: {}".format(int(median)))

# Mode of Total transaction amount in Credit Card Customers
mode = data['Total_Trans_Amt'].mode()
print("The mode of Total transaction amount: {}".format((mode)))

# The standard deviation of Total transaction amount in Credit Card Customers
std = data['Total_Trans_Amt'].std()
print("The std Total transaction amount of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Total transaction amount: 4404
# The median of Total transaction amount: 3899
# The mode of Total transaction amount: 0    4253
# 1    4509
# dtype: int64
# The std Total transaction amount of Credit Card Customers: 3397.13

# %% [markdown]
# ### Total Transaction Count

# %%
# Mean of Total transaction count Credit Card Customers
mean = data['Total_Trans_Ct'].mean()
print("The mean of Total transaction count: {:.0f}".format(round(mean,2)))

# Median of Total transaction count in Credit Card Customers
median = data['Total_Trans_Ct'].median()
print("The median of Total transaction count: {}".format(int(median)))

# Mode of Total transaction count in Credit Card Customers
mode = data['Total_Trans_Ct'].mode()
print("The mode of Total transaction count: {}".format(int(mode)))

# The standard deviation of Total transaction count in Credit Card Customers
std = data['Total_Trans_Ct'].std()
print("The std Total transaction count of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Total transaction count: 65
# The median of Total transaction count: 67
# The mode of Total transaction count: 81
# The std Total transaction count of Credit Card Customers: 23.47

# %% [markdown]
# ### Total Change in Transaction Count (Q4 over Q1)

# %%
# Mean of Total change in transaction count (Q4 over Q1) Credit Card Customers
mean = data['Total_Ct_Chng_Q4_Q1'].mean()
print("The mean of Total change in transaction count (Q4 over Q1): {:.2f}".format(round(mean,2)))

# Median of Total change in transaction count (Q4 over Q1) in Credit Card Customers
median = data['Total_Ct_Chng_Q4_Q1'].median()
print("The median of Total change in transaction count (Q4 over Q1): {:.2f}".format(float(median)))

# Mode of Total change in transaction count (Q4 over Q1) in Credit Card Customers
mode = data['Total_Ct_Chng_Q4_Q1'].mode()
print("The mode of Total change in transaction count (Q4 over Q1): {:.2f}".format(float(mode)))

# The standard deviation of transaction count (Q4 over Q1) in Credit Card Customers
std = data['Total_Ct_Chng_Q4_Q1'].std()
print("The std Total change in transaction count of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Total change in transaction count (Q4 over Q1): 0.71
# The median of Total change in transaction count (Q4 over Q1): 0.70
# The mode of Total change in transaction count (Q4 over Q1): 0.67
# The std Total change in transaction count of Credit Card Customers: 0.24

# %% [markdown]
# ### Average Utilization Ratio

# %%
# Mean of Average Utilization Ratio Credit Card Customers
mean = data['Avg_Utilization_Ratio'].mean()
print("The mean of Average Utilization Ratio: {:.2f}".format(round(mean,2)))

# Median of Average Utilization Ratio in Credit Card Customers
median = data['Avg_Utilization_Ratio'].median()
print("The median of Average Utilization Ratio: {:.2f}".format(float(median)))

# Mode of Average Utilization Ratio in Credit Card Customers
mode = data['Avg_Utilization_Ratio'].mode()
print("The mode of Average Utilization Ratio: {}".format(float(mode)))

# The standard deviation of Average Utilization Ratio in Credit Card Customers
std = data['Avg_Utilization_Ratio'].std()
print("The std Average Utilization Ratio of Credit Card Customers: {:.2f}".format(std))
# Out:
# The mean of Average Utilization Ratio: 0.27
# The median of Average Utilization Ratio: 0.18
# The mode of Average Utilization Ratio: 0.0
# The std Average Utilization Ratio of Credit Card Customers: 0.28

# %% [markdown]
# ## 3. Categorical : Proportion
# 7 Categorical Data : ClientNum, Attrition Flag, Gender, etc.

# %% [markdown]
# ### Client Number

# %%
# Proportion of Client Number
proportion = pd.DataFrame(data['CLIENTNUM'].value_counts())
proportion = proportion.rename(columns={'CLIENTNUM':'Amount'})
proportion['Proportion(%)'] = data['CLIENTNUM'].value_counts(normalize=True)
proportion = proportion.rename_axis('Client Number').reset_index()

# show the five first rows
proportion.head()
# Out:
#    Client Number  Amount  Proportion(%)
# 0      780097533       1       0.000099
# 1      720049083       1       0.000099
# 2      717376758       1       0.000099
# 3      720598308       1       0.000099
# 4      719930658       1       0.000099

# %% [markdown]
# ### Attrition Flag

# %%
# Proportion of Attrition Flag
proportion = pd.DataFrame(data['Attrition_Flag'].value_counts())
proportion = proportion.rename(columns={'Attrition_Flag':'Amount'})
proportion['Proportion(%)'] = data['Attrition_Flag'].value_counts(normalize=True)
proportion = proportion.rename_axis('Attrition Flag').reset_index()

# show the five first rows
proportion.head()
# Out:
#       Attrition Flag  Amount  Proportion(%)
# 0  Existing Customer    8500        0.83934
# 1  Attrited Customer    1627        0.16066

# %% [markdown]
# ### Gender

# %%
# Proportion of Gender
proportion = pd.DataFrame(data['Gender'].value_counts())
proportion = proportion.rename(columns={'Gender':'Amount'})
proportion['Proportion(%)'] = data['Gender'].value_counts(normalize=True)
proportion = proportion.rename_axis('Gender').reset_index()

# show the five first rows
proportion.head()
# Out:
#   Gender  Amount  Proportion(%)
# 0      F    5358       0.529081
# 1      M    4769       0.470919

# %% [markdown]
# ### Educational Level

# %%
# Proportion of Educational Level
proportion = pd.DataFrame(data['Education_Level'].value_counts())
proportion = proportion.rename(columns={'Education_Level':'Amount'})
proportion['Proportion(%)'] = data['Education_Level'].value_counts(normalize=True)
proportion = proportion.rename_axis('Education Level').reset_index()

# show the five first rows
proportion.head()
# Out:
#   Education Level  Amount  Proportion(%)
# 0        Graduate    3128       0.308877
# 1     High School    2013       0.198776
# 2         Unknown    1519       0.149995
# 3      Uneducated    1487       0.146835
# 4         College    1013       0.100030

# %% [markdown]
# ### Marital Status

# %%
# Proportion of Marital Status
proportion = pd.DataFrame(data['Marital_Status'].value_counts())
proportion = proportion.rename(columns={'Marital_Status':'Amount'})
proportion['Proportion(%)'] = data['Marital_Status'].value_counts(normalize=True)
proportion = proportion.rename_axis('Marital Status Level').reset_index()

# show the five first rows
proportion.head()
# Out:
#   Marital Status Level  Amount  Proportion(%)
# 0              Married    4687       0.462822
# 1               Single    3943       0.389355
# 2              Unknown     749       0.073961
# 3             Divorced     748       0.073862

# %% [markdown]
# ### Income Category

# %%
# Proportion of Income Category
proportion = pd.DataFrame(data['Income_Category'].value_counts())
proportion = proportion.rename(columns={'Income_Category':'Amount'})
proportion['Proportion(%)'] = data['Income_Category'].value_counts(normalize=True)
proportion = proportion.rename_axis('Income_Category').reset_index()

# show the five first rows
proportion.head()
# Out:
#   Income_Category  Amount  Proportion(%)
# 0  Less than $40K    3561       0.351634
# 1     $40K - $60K    1790       0.176755
# 2    $80K - $120K    1535       0.151575
# 3     $60K - $80K    1402       0.138442
# 4         Unknown    1112       0.109805

# %% [markdown]
# ### Card Category

# %%
# Proportion of Card Category
proportion = pd.DataFrame(data['Card_Category'].value_counts())
proportion = proportion.rename(columns={'Card_Category':'Amount'})
proportion['Proportion(%)'] = data['Card_Category'].value_counts(normalize=True)
proportion = proportion.rename_axis('Card Category').reset_index()

# show the five first rows
proportion.head()
# Out:
#   Card Category  Amount  Proportion(%)
# 0          Blue    9436       0.931767
# 1        Silver     555       0.054804
# 2          Gold     116       0.011455
# 3      Platinum      20       0.001975

# %%
# data.groupby(['A'], as_index=True).apply(lambda x: x.sample(n=200, random_state=1))

# %% [markdown]
# #Separate dataset into two dataset in attrition_flag
# * Existing customer
# * Attrited customer

# %%
# data.groupby(['Attrition_Flag'], as_index=True)
existing_data = data[(data.Attrition_Flag == 'Existing Customer')]
attrited_data = data[(data.Attrition_Flag == 'Attrited Customer')]
existing_data.head(), attrited_data.head()
# Out:
# (   CLIENTNUM     Attrition_Flag  ...  Total_Ct_Chng_Q4_Q1 Avg_Utilization_Ratio
#  0  768805383  Existing Customer  ...                1.625                 0.061
#  1  818770008  Existing Customer  ...                3.714                 0.105
#  2  713982108  Existing Customer  ...                2.333                 0.000
#  3  769911858  Existing Customer  ...                2.333                 0.760
#  4  709106358  Existing Customer  ...                2.500                 0.000
#
#  [5 rows x 21 columns],
#      CLIENTNUM     Attrition_Flag  ...  Total_Ct_Chng_Q4_Q1 Avg_Utilization_Ratio
#  21  708508758  Attrited Customer  ...                0.600                 0.000
#  39  708300483  Attrited Customer  ...                0.143                 0.077
#  51  779471883  Attrited Customer  ...                0.900                 0.562
#  54  714374133  Attrited Customer  ...                0.364                 0.000
# ...

# %% [markdown]
# #Analyze the distribution of each numerical column variable

# %% [markdown]
# ##Customer Age

# %% [markdown]
# ###Existing Customer

# %%
import matplotlib.pyplot as plt

# %%
average = existing_data['Customer_Age'].mean()
median = existing_data['Customer_Age'].median()
mode = existing_data['Customer_Age'].mode()
plt.figure(figsize=(12,7))
sns.histplot(data=existing_data, x='Customer_Age', kde=True, discrete=True)
plt.axvline(average, color='r', linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', linestyle='dashed', linewidth=3, label='Mode')
plt.axvline(mode[1], color='black', linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited customer

# %%
attrited_data['Customer_Age'].value_counts()
# Out:
# 48    85
# 43    85
# 44    84
# 46    82
# 45    79
# 49    79
# 41    76
# 47    76
# 50    71
# 54    69
# 40    64
# 42    62
# 53    59
# 52    58
# 51    58
# 55    51
# 39    48
# 38    47
# 56    43
# 59    40
# 37    37
# 57    33
# 58    24
# 36    24
# 35    21
# 33    20
# 34    19
# 61    17
# 32    17
# 62    17
# 30    15
# 60    13
# 31    13
# 65     9
# 63     8
# 29     7
# 26     6
# 64     5
# 27     3
# 66     1
# 28     1
# 68     1
# Name: Customer_Age, dtype: int64

# %%
average = attrited_data['Customer_Age'].mean()
median = attrited_data['Customer_Age'].median()
mode = attrited_data['Customer_Age'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Customer_Age', kde=True, discrete=True)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.axvline(mode[1], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Dependent Count

# %% [markdown]
# ###Existing Customer

# %%
existing_data['Dependent_count'].mode()
# Out:
# 0    3
# dtype: int64

# %%
average = existing_data['Dependent_count'].mean()
median = existing_data['Dependent_count'].median()
mode = existing_data['Dependent_count'].mode()
plt.figure(figsize=(12,7))
sns.countplot(data=existing_data, x='Dependent_count')
plt.axvline(average, color='r', linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# Variabel ini tidak cocok dicari distribusinya karena sifat variabelnya adalah diskrit begitupun dengan Attrited Customer

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Dependent_count'].mean()
median = attrited_data['Dependent_count'].median()
mode = attrited_data['Dependent_count'].mode()
plt.figure(figsize=(12,7))
sns.countplot(data=attrited_data, x='Dependent_count')
plt.axvline(average, color='r', linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Months on Book

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Months_on_book'].mean()
median = existing_data['Months_on_book'].median()
mode = existing_data['Months_on_book'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Months_on_book', kde=True, discrete=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Months_on_book'].mean()
median = attrited_data['Months_on_book'].median()
mode = attrited_data['Months_on_book'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Months_on_book', kde=True, discrete=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Total Relationship Count

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Total_Relationship_Count'].mean()
median = existing_data['Total_Relationship_Count'].median()
mode = existing_data['Total_Relationship_Count'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.countplot(data=existing_data, x='Total_Relationship_Count')

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Total_Relationship_Count'].mean()
median = attrited_data['Total_Relationship_Count'].median()
mode = attrited_data['Total_Relationship_Count'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.countplot(data=attrited_data, x='Total_Relationship_Count')

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Months Inactive 12 Month

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Months_Inactive_12_mon'].mean()
median = existing_data['Months_Inactive_12_mon'].median()
mode = existing_data['Months_Inactive_12_mon'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.countplot(data=existing_data, x='Months_Inactive_12_mon')

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Months_Inactive_12_mon'].mean()
median = attrited_data['Months_Inactive_12_mon'].median()
mode = attrited_data['Months_Inactive_12_mon'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.countplot(data=attrited_data, x='Months_Inactive_12_mon')

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Contacts Count 12 Month

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Contacts_Count_12_mon'].mean()
median = existing_data['Contacts_Count_12_mon'].median()
mode = existing_data['Contacts_Count_12_mon'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.countplot(data=existing_data, x='Contacts_Count_12_mon')

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Contacts_Count_12_mon'].mean()
median = attrited_data['Contacts_Count_12_mon'].median()
mode = attrited_data['Contacts_Count_12_mon'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.countplot(data=attrited_data, x='Contacts_Count_12_mon')

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Credit Limit

# %% [markdown]
# ###Exiting Customer

# %%
existing_data['Credit_Limit'].mode()
# Out:
# 0    34516.0
# dtype: float64

# %%
average = existing_data['Credit_Limit'].mean()
median = existing_data['Credit_Limit'].median()
mode = existing_data['Credit_Limit'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Credit_Limit', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Credit_Limit'].mean()
median = attrited_data['Credit_Limit'].median()
mode = attrited_data['Credit_Limit'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Credit_Limit', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Total Revolving Balance

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Total_Revolving_Bal'].mean()
median = existing_data['Total_Revolving_Bal'].median()
mode = existing_data['Total_Revolving_Bal'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Total_Revolving_Bal', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Total_Revolving_Bal'].mean()
median = attrited_data['Total_Revolving_Bal'].median()
mode = attrited_data['Total_Revolving_Bal'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Total_Revolving_Bal', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Average Open to Buy

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Avg_Open_To_Buy'].mean()
median = existing_data['Avg_Open_To_Buy'].median()
mode = existing_data['Avg_Open_To_Buy'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Avg_Open_To_Buy', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Avg_Open_To_Buy'].mean()
median = attrited_data['Avg_Open_To_Buy'].median()
mode = attrited_data['Avg_Open_To_Buy'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Avg_Open_To_Buy', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Total Amount Change Q4 over Q1

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Total_Amt_Chng_Q4_Q1'].mean()
median = existing_data['Total_Amt_Chng_Q4_Q1'].median()
mode = existing_data['Total_Amt_Chng_Q4_Q1'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Total_Amt_Chng_Q4_Q1', kde=True, bins=50, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Total_Amt_Chng_Q4_Q1'].mean()
median = attrited_data['Total_Amt_Chng_Q4_Q1'].median()
mode = attrited_data['Total_Amt_Chng_Q4_Q1'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Total_Amt_Chng_Q4_Q1', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Total Transaction Amount

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Total_Trans_Amt'].mean()
median = existing_data['Total_Trans_Amt'].median()
mode = existing_data['Total_Trans_Amt'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Total_Trans_Amt', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Total_Trans_Amt'].mean()
median = attrited_data['Total_Trans_Amt'].median()
mode = attrited_data['Total_Trans_Amt'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Total_Trans_Amt', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Total Transaction Count

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Total_Trans_Ct'].mean()
median = existing_data['Total_Trans_Ct'].median()
mode = existing_data['Total_Trans_Ct'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Total_Trans_Ct', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Total_Trans_Ct'].mean()
median = attrited_data['Total_Trans_Ct'].median()
mode = attrited_data['Total_Trans_Ct'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Total_Trans_Ct', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Total Change in Transaction Count (Q4 over Q1)

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Total_Ct_Chng_Q4_Q1'].mean()
median = existing_data['Total_Ct_Chng_Q4_Q1'].median()
mode = existing_data['Total_Ct_Chng_Q4_Q1'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Total_Ct_Chng_Q4_Q1', kde=True, bins=50, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Total_Ct_Chng_Q4_Q1'].mean()
median = attrited_data['Total_Ct_Chng_Q4_Q1'].median()
mode = attrited_data['Total_Ct_Chng_Q4_Q1'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Total_Ct_Chng_Q4_Q1', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ##Average Utilization Ratio

# %% [markdown]
# ###Existing Customer

# %%
average = existing_data['Avg_Utilization_Ratio'].mean()
median = existing_data['Avg_Utilization_Ratio'].median()
mode = existing_data['Avg_Utilization_Ratio'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=existing_data, x='Avg_Utilization_Ratio', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# ###Attrited Customer

# %%
average = attrited_data['Avg_Utilization_Ratio'].mean()
median = attrited_data['Avg_Utilization_Ratio'].median()
mode = attrited_data['Avg_Utilization_Ratio'].mode()

fig, ax = plt.subplots(1, 1, figsize=(12, 7))
sns.histplot(data=attrited_data, x='Avg_Utilization_Ratio', kde=True, ax=ax)

plt.axvline(average, color='r', ymax=0.95, linestyle='solid', linewidth=3, label='Mean')
plt.axvline(median, color='y', ymax=0.95, linestyle='dotted', linewidth=3, label='Median')
plt.axvline(mode[0], color='purple', ymax=0.95, linestyle='dashed', linewidth=3, label='Mode')
plt.show()

# %% [markdown]
# #Hypothesis
# testing whether the average of credit limit and avg of avg open to buy are the same.

# %% [markdown]
# ## Z Test
#
# H0: The average of credit limit variable is the same with the average of average open to buy variable

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats import weightstats as stests

#Set Value
confidence_level = 0.95
alpha = 1-confidence_level
data1= data['Credit_Limit'].sample(n=150)
data2=data['Avg_Open_To_Buy'].sample(n=150)
data1_mean = np.mean(data1)
data2_mean = np.mean(data2)
print("Credit Limit mean value:",data1_mean)
print("Avg Open To Buy mean value:",data2_mean)
print('')

data1_std = np.std(data1)
data2_std = np.std(data2)
print("Credit Limit std value:",data1_std)
print("Avg Open To Buy std value:",data2_std)
print('')

#Test
ztest ,pval1 = stests.ztest(x1= data1,
                            x2=data2, 
                            value=0,alternative='two-sided')
if pval1 < 0.05:
  print("Reject the hypothesis")
  print("Because the pvalue {:.2f} < {:.2f}".format(pval1, alpha))
else:
  print("Accept the hypothesis")
  print("Because the pvalue {:.2f} > {:.2f}".format(pval1, alpha))
# Out:
# Credit Limit mean value: 8402.484666666667
# Avg Open To Buy mean value: 6983.008000000001
#
# Credit Limit std value: 8588.70938460284
# Avg Open To Buy std value: 9051.906568213644
#
# Accept the hypothesis
# Because the pvalue 0.16 > 0.05

# %% [markdown]
# ## T test
# H0: The average of credit limit variable is the same with the average of average open to buy variable

# %%
from scipy.stats import ttest_ind
import numpy as np

#Set Value
confidence_level = 0.95
alpha = 1-confidence_level

x1= data['Credit_Limit'].sample(n=150)
x2= data['Avg_Open_To_Buy'].sample(n=150)

x1_mean = np.mean(x1)
x2_mean = np.mean(x2)
print("Credit Limit mean value:",x1_mean)
print("Avg Open To Buy mean value:",x2_mean)
print('')

x1_std = np.std(x1)
x2_std = np.std(x2)
print("Credit Limit std value:",x1_std)
print("Avg Open To Buy std value:",x2_std)
print('')

#Test
ttest,pval = ttest_ind(x1,x2)
print("p-value",pval)
print('')

if pval < 0.05:
  print("Reject the hypothesis")
  print("Because the pvalue {:.2f} < {:.2f}".format(pval, alpha))
else :
  print("Accept the hypothesis")
  print("Because the pvalue {:.2f} > {:.2f}".format(pval, alpha))
# Out:
# Credit Limit mean value: 9021.614666666666
# Avg Open To Buy mean value: 6389.8200000000015
#
# Credit Limit std value: 9394.224766840432
# Avg Open To Buy std value: 8096.697340290464
#
# p-value 0.01005966258105006
#
# Reject the hypothesis
# Because the pvalue 0.01 < 0.05

# %% [markdown]
# ## Explanation
#
#
# *   Dalam case ini kami lebih memilih untuk menggunakan z-test, karena jumlah sample yang digunakan >30 dan standar deviasi yang telah diketahui diawal hipotesis. Walaupun secara hasil, baik z-test maupun t-test menunjukan hasil yang kurang lebih sama.
#
# *   Kedua metode hampir selalu menghasilkan kesimpulan yang sama yaitu menerima H0, karena kedua variabel memang memiliki korelasi yang kuat. Data Avg_Open_To_Buy didapatkan dari hasil Pengurangan Credit_Limit dengan Total_Revolving_Bal. Dimana Modus dari data Total_Revolving_Bal kebanyakan bernilai 0, sehingga data Credit_Limit dan Avg_Open_To_Buy akan memiliki nilai yang kebanyakan sama(Alasan mengapa nilai korelasi kedua variabel adalah 1)
